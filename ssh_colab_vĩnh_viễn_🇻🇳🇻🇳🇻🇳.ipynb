# %% [markdown]
# <a href="https://colab.research.google.com/github/Quangvov/sshcolablivetime/blob/main/ssh_colab_v%C4%A9nh_vi%E1%BB%85n_%F0%9F%87%BB%F0%9F%87%B3%F0%9F%87%BB%F0%9F%87%B3%F0%9F%87%BB%F0%9F%87%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ssh colab vĩnh viễn 🇻🇳
#
# Cảnh báo không được tắt tab này ssh sẽ sập

# %%
#@title **check gpu (không cần thiết) 🇻🇳❤🇻🇳**

# !nvidia-smi
from numba import jit, cuda
import numpy as np
# to measure exec time
from timeit import default_timer as timer

# normal function to run on cpu
def func(a):                                
    for i in range(10000000):
        a[i]+= 1    

                        
def func2(a):
    for i in range(10000000):
        a[i]+= 1
if __name__=="__main__":
    n = 10000000                            
    a = np.ones(n, dtype = np.float64)
    b = np.ones(n, dtype = np.float32)
    
    start = timer()
    func(a)
    print("without GPU:", timer()-start)    
    
    start = timer()
    func2(a)
    print("with GPU:", timer()-start)

# %%
#@title **1tạo tài khoản ssh 🇻🇳🇻🇳🇻🇳🇻🇳**
#@markdown tên tài khoản và mật khẩu 🇻🇳🇻🇳🇻🇳

import os

username = "" #@param {type:"string"}
password = "" #@param {type:"string"}

print("Creating User and Setting it up")

# Creation of user
os.system(f"useradd -m {username}")

# Add user to sudo group
os.system(f"adduser {username} sudo")
    
# Set password of user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")

# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")

print(f"tên tài khoản đã được tạo 🇻🇳🇻🇳🇻🇳 `{username}` và mật khẩu 🇻🇳  `{password}`")

# %%
#@title **2 chạy ssh tmate 🇻🇳🇻🇳🇻🇳**
# !pkill -9 tmate
# !wget -nc https://github.com/tmate-io/tmate/releases/download/2.4.0/tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !tar --skip-old-files -xvf tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !rm -f nohup.out; bash -ic 'nohup ./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock new-session -d & disown -a' >/dev/null 2>&1
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock wait tmate-ready
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with SSH address: #{tmate_ssh}"
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with web: #{tmate_web}"

# %%
#@title **3 Kích hoạt để ssh colab chạy vĩnh viễn 🇻🇳🇻🇳🇻🇳** 

alive = True #@param {type:'boolean'}

! sleep ...
